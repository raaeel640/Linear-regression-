# %% [markdown]
# <a href="https://colab.research.google.com/github/raaeel640/Linear-regression-/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ce0f9b9-407e-4987-89d7-98cd81ed72a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ce0f9b9-407e-4987-89d7-98cd81ed72a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('placement (1).csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
plt.show()

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# fit =train the model
# Out:
# LinearRegression()

# %%
x_test.head(10)
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87

# %%
y_test.head(10)
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# Name: package, dtype: float64

# %%
lr.predict(x_test.iloc[3].values.reshape(1,1))
# output shows that a person having GPA 6.22 can have a package of 2.57 but there is a minor difference in this predicted an actual one
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.57434935])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('packages')
plt.show()
# plt.scatter(x_test,y_test)
# this is the best fit line found by y intercept(c) and slope(m) from equation y=mx+c

# %%
m=lr.coef_
m
# Out:
# array([0.55795197])

# %%
c=lr.intercept_
c
# Out:
# np.float64(-0.8961119222429144)

# %%
# y=mx+cto find y (package) we will give CGPA(x)
m * 6.22 + c
# it shows the GPA that we found by prediction from line 32 and we are proving it any value of CPGA it will calculate the package for that
# Out:
# array([2.57434935])

# %%
m*8.43+c
# so for a student with CGPA=8.43 which is not in data it has calculated the package
# it shows a relationship between cgpa and package
# Out:
# array([3.80742321])

# %%
# m>weightage(slope) shows the dependence of output on input
# if in case mx*CGPA becomes zero then package will be directly dependent on C s

# %%
class LinearRegression:
   def __init__(self):
    self.m= None
    self.c= None

   def fit(self,X_train,y_train):
    num =0
    den=0


    for i in range(x_train.shape[0]):
       num = num + ((x_train[i]-x_train.mean())*(y_train[i]-y_train.mean()))
      #  apply formula for first student and then will do it for all others cz of loop
       den = den + (x_train[i]-x_train.mean())**2
      #  finding denominator

    self.m=num/den
    self.c=y_train.mean()-(self.m*x_train.mean())
    print(self.m)
    print(self.c)

   def predict(self,X_test):
    print(x_test)
    return self.m*X_test + self.c

# %%
x=df.iloc[:,0:1].values
y=df.iloc[:,-1].values
x
# showing all gpas
# Out:
# array([[6.89],
#        [5.12],
#        [7.82],
#        [7.42],
#        [6.94],
#        [7.89],
#        [6.73],
#        [6.75],
#        [6.09],
#        [8.31],
#        [5.32],
#        [6.61],
#        [8.94],
#        [6.93],
#        [7.73],
#        [7.25],
#        [6.84],
#        [5.38],
#        [6.94],
#        [7.48],
#        [7.28],
#        [6.85],
#        [6.14],
#        [6.19],
#        [6.53],
#        [7.28],
#        [8.31],
#        [5.42],
#        [5.94],
#        [7.15],
#        [7.36],
#        [8.1 ],
#        [6.96],
#        [6.35],
#        [7.34],
#        [6.87],
#        [5.99],
#        [5.9 ],
#        [8.62],
#        [7.43],
#        [9.38],
#        [6.89],
#        [5.95],
#        [7.66],
#        [5.09],
#        [7.87],
#        [6.07],
#        [5.84],
#        [8.63],
#        [8.87],
#        [9.58],
#        [9.26],
#        [8.37],
#        [6.47],
#        [6.86],
#        [8.2 ],
#        [5.84],
#        [6.6 ],
# ...

# %%
y
# showing all packages
# Out:
# array([3.26, 1.98, 3.25, 3.67, 3.57, 2.99, 2.6 , 2.48, 2.31, 3.51, 1.86,
#        2.6 , 3.65, 2.89, 3.42, 3.23, 2.35, 2.09, 2.98, 2.83, 3.16, 2.93,
#        2.3 , 2.48, 2.71, 3.65, 3.42, 2.16, 2.24, 3.49, 3.26, 3.89, 3.08,
#        2.73, 3.42, 2.87, 2.84, 2.43, 4.36, 3.33, 4.02, 2.7 , 2.54, 2.76,
#        1.86, 3.58, 2.26, 3.26, 4.09, 4.62, 4.43, 3.79, 4.11, 2.61, 3.09,
#        3.39, 2.74, 1.94, 3.09, 3.31, 2.19, 1.61, 2.09, 4.25, 2.92, 3.81,
#        1.63, 2.89, 2.99, 2.94, 2.35, 3.34, 3.62, 4.03, 3.44, 3.28, 3.15,
#        4.6 , 2.21, 3.  , 3.44, 2.2 , 2.17, 3.49, 1.53, 1.48, 2.77, 3.55,
#        1.48, 2.72, 2.66, 2.14, 4.  , 3.08, 2.42, 2.79, 2.61, 2.84, 3.83,
#        3.24, 4.14, 3.52, 1.37, 3.  , 3.74, 2.82, 2.19, 2.59, 3.54, 4.06,
#        3.76, 2.25, 4.1 , 2.37, 1.87, 4.21, 3.33, 2.99, 2.88, 2.65, 1.73,
#        3.02, 2.01, 2.3 , 2.31, 3.16, 2.6 , 3.11, 3.34, 3.12, 2.49, 2.01,
#        2.48, 2.58, 2.83, 2.6 , 2.1 , 3.13, 3.89, 2.4 , 3.15, 3.18, 3.04,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
x_train.shape
# Out:
# (160, 1)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# [0.55795197]
# [-0.89611192]

# %%
x_train[0]
# finding the cgpa of first student
# Out:
# array([7.14])

# %%
x_train.mean()
# Out:
# np.float64(6.989937500000001)

# %%
x_test[3]
# Out:
# array([6.22])

# %%
print(lr.predict(x_test[3]))
# Out:
# [[8.58]
#  [7.15]
#  [5.88]
#  [6.22]
#  [4.57]
#  [4.79]
#  [5.32]
#  [6.86]
#  [8.35]
#  [6.87]
#  [8.94]
#  [7.9 ]
#  [6.93]
#  [5.91]
#  [7.32]
#  [7.82]
#  [5.09]
#  [7.42]
#  [6.94]
#  [7.73]
#  [6.19]
#  [7.28]
#  [6.73]
#  [7.2 ]
#  [8.21]
#  [6.75]
#  [7.87]
#  [7.6 ]
#  [8.63]
#  [5.12]
#  [8.15]
#  [7.36]
#  [8.31]
#  [6.6 ]
#  [6.59]
#  [7.47]
#  [7.93]
#  [6.29]
#  [6.37]
#  [6.47]]
# [2.57434935]
